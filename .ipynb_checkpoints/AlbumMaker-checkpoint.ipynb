# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
import numpy as np
import imageio
from PIL import Image, ExifTags
# from iptcinfo3 import IPTCInfo

# %%
make_html('_canadian_rockies_2021')
# Out:
# <a href="Gallery/large_canadian_rockies_2021/2021-08-08_21_00_23.jpg" data-size="8000x6000" data-med="Gallery/med_canadian_rockies_2021/2021-08-11_21_09_42.jpg" data-med-size="4000x1800" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-08_21_00_23.jpg" alt="" id="thumb" />
# <figure>Scouting the Miette thrust, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-11_21_09_42.jpg" data-size="4000x1800" data-med="Gallery/med_canadian_rockies_2021/2021-08-15_15_50_54.jpg" data-med-size="3937x2996" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-11_21_09_42.jpg" alt="" id="thumb" />
# <figure>Setting up camp near Slide Mountain, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-11_21_24_46.jpg" data-size="4000x1800" data-med="Gallery/med_canadian_rockies_2021/2021-08-26_15_49_07.jpg" data-med-size="5472x3648" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-11_21_24_46.jpg" alt="" id="thumb" />
# <figure>Camping near the Slide Mountain section, Miette thrust, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-12_12_53_29.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-08_21_00_23.jpg" data-med-size="8000x6000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-12_12_53_29.jpg" alt="" id="thumb" />
# <figure>Devonian stromatoporoids (reef-building, calcifying sea sponges) from the Miette carbonate buildup in Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-12_13_01_03.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-12_13_01_03.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-12_13_01_03.jpg" alt="" id="thumb" />
# <figure>Well-preserved stromatoporoid (Devonian calcifying sea sponge); vertical structures are called 'pillars', while small chambers are called 'galleries'. </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-12_16_35_21.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-12_16_49_44.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-12_16_35_21.jpg" alt="" id="thumb" />
# <figure>Devonian reef buildup formed by stromatoporoids (calcifying sea sponges), with morphologies ranging from bulbous to branching (Amphipora). </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-12_16_42_30.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-12_16_35_21.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-12_16_42_30.jpg" alt="" id="thumb" />
# <figure>Well-preserved stromatoporoid (Devonian calcifying sponge) on Slide Mountain, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-12_16_49_44.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-16_12_47_49.jpg" data-med-size="5472x3648" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-12_16_49_44.jpg" alt="" id="thumb" />
# <figure>Devonian stromatoporoiod framestone in the Slide Mountain section, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-14_10_24_38.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-26_13_37_15.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-14_10_24_38.jpg" alt="" id="thumb" />
# <figure>Devonian branching stromatoporoid (Amphipora) packstone, Miette carbonate buildup, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-14_13_51_14.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-26_14_28_14.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-14_13_51_14.jpg" alt="" id="thumb" />
# <figure>Large (40 cm diameter) stromatoporoid, Miette carbonate buildup, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-15_15_50_54.jpg" data-size="3937x2996" data-med="Gallery/med_canadian_rockies_2021/2021-08-12_16_42_30.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-15_15_50_54.jpg" alt="" id="thumb" />
# <figure>Kristyn inspects a Devonian reef buildup, Slide Mountain, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-16_12_47_49.jpg" data-size="5472x3648" data-med="Gallery/med_canadian_rockies_2021/2021-08-27_13_02_03.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-16_12_47_49.jpg" alt="" id="thumb" />
# <figure>Aerial view of the Slide Mountain section, Miette thrust, Jasper National Park </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-17_18_12_19.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-26_11_12_22.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08
jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-22_12_02_16.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-29_13_52_42.jpg" alt="" id="thumb" />
# <figure>Large Mississippian 'honeycomb' tabulate coral (Lithostrotionella) in growth position. The coral is growing up and out, and then over topography (intersecting a pocket of wackestone). </figure>
# </a>
#
# <a href="Gallery/large_canadian_rockies_2021/2021-08-29_13_55_45.jpg" data-size="4000x3000" data-med="Gallery/med_canadian_rockies_2021/2021-08-12_12_53_29.jpg" data-med-size="4000x3000" class="demo-gallery__img--main" data-author="Stacey Edmonsond">
# <img src="Gallery/thumb_canadian_rockies_2021/2021-08-29_13_55_45.jpg" alt="" id="thumb" />
# <figure>Missippian tabulate 'honeycomb' coral (Lithostrotionella), Mount Head Formation, Mount Gass. </figure>
# </a>

# %%
def make_html(suffix):
    directory='Gallery/large'+suffix+'/'
    directory_m='Gallery/med'+suffix+'/'
    directory_t='Gallery/thumb'+suffix+'/'
    
    files=os.listdir(directory)
    files = [f for f in files if '.jpg' in f]

    tstamps = []
    for f in files:

        img=f
        
#         info = IPTCInfo(directory+img)
        
        exif_img = Image.open(directory+img)
        exif = { ExifTags.TAGS[k]: v for k, v in exif_img._getexif().items() if k in ExifTags.TAGS }
        timestamp=exif['DateTimeOriginal']
        tstamps.append(timestamp)

    files=[x for _,x in sorted(zip(tstamps,files))]


    files_t=os.listdir(directory_t)
    files_t = [f for f in files_t if '.jpg' in f]

    tstamps = []
    for f in files_t:

        img=f

        exif_img = Image.open(directory_t+img)
        exif = { ExifTags.TAGS[k]: v for k, v in exif_img._getexif().items() if k in ExifTags.TAGS }
        timestamp=exif['DateTimeOriginal']
        tstamps.append(timestamp)

    files_t=[x for _,x in sorted(zip(tstamps,files_t))]
    
    files_m=os.listdir(directory_m)
    files_m = [f for f in files_m if '.jpg' in f]

    tstamps = []
    for f in files_m:

        img=f

        exif_img = Image.open(directory_m+img)
        exif = { ExifTags.TAGS[k]: v for k, v in exif_img._getexif().items() if k in ExifTags.TAGS }
        timestamp=exif['DateTimeOriginal']
        tstamps.append(timestamp)

    files_t=[x for _,x in sorted(zip(tstamps,files_m))]


    for f,f_t,f_m in zip(files,files_t,files_m):
        img=f
        img_t=f_t
        img_m=f_m
        exif_img = Image.open(directory+img)
        exif = { ExifTags.TAGS[k]: v for k, v in exif_img._getexif().items() if k in ExifTags.TAGS }
        if 'ImageDescription' in exif.keys():
            comm = exif['ImageDescription']
        else:
                comm = ''

        if 'Artist' in exif.keys():
            auth=exif['Artist']
        else:
            auth='Blake Dyer'
        

        im = imageio.imread(directory+img)
        im_m = imageio.imread(directory_m+img_m)
        print('<a href="'+directory+img+'" data-size="'+str(im.shape[1])+'x'+str(im.shape[0])+'" '+
              'data-med="'+directory_m+img_m+'" data-med-size="'+str(im_m.shape[1])+'x'+str(im_m.shape[0])+'" '+
              'class="demo-gallery__img--main" data-author="'+auth+'">')

        print('<img src="'+directory_t+img_t+'" alt="" id="thumb" />')

        print('<figure>'+comm+' </figure>')
        print('</a>')
        print('')
